# %% [markdown]
# # Dependências

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # Ambiente

# %%
environment_name = 'CarRacing-v0'
env = gym.make(environment_name)

# %%
env.close()

# %%
episodes = 2
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Track generation: 1076..1356 -> 280-tiles track
# Episode:1 Score:-28.315412186380303
# Track generation: 1302..1632 -> 330-tiles track
# Episode:2 Score:-39.20972644376962

# %% [markdown]
# # Treinando modelo

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('Training','Logs')
model = PPO('CnnPolicy', env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps = 10000000)
# Out:
# Track generation: 1068..1339 -> 271-tiles track
# Logging to Training\Logs\PPO_12
# Track generation: 1094..1373 -> 279-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1244..1559 -> 315-tiles track
# Track generation: 1338..1677 -> 339-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 157  |
# |    iterations      | 1    |
# |    time_elapsed    | 12   |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1100..1389 -> 289-tiles track
# Track generation: 1196..1499 -> 303-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 2           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.061949708 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0517     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0383     |
# |    std                  | 0.734       |
# |    value_loss           | 0.0597      |
# -----------------------------------------
# Track generation: 1339..1678 -> 339-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 3           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.045379154 |
# |    clip_fraction        | 0.367       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.31       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0533     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0329     |
# |    std                  | 0.727       |
# |    value_loss           | 0.17        |
# -----------------------------------------
# Track generation: 1205..1514 -> 309-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1257..1575 -> 318-tiles track
# Track generation: 1323..1658 -> 335-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 4           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.047105074 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0331     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0421     |
# |    std                  | 0.726       |
# |    value_loss           | 0.0857      |
# -----------------------------------------
# Track generation: 1104..1384 -> 280-tiles track
# Track generation: 1226..1543 -> 317-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 5          |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.06884651 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.28      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.069     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0376    |
# |    std                  | 0.721      |
# |    value_loss           | 0.0748     |
# ----------------------------------------
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 6          |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.06049657 |
# |    clip_fraction        | 0.38       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.26      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0371    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0386    |
# |    std                  | 0.716      |
# |    value_loss           | 0.0946     |
# ----------------------------------------
# Track generation: 1117..1401 -> 284-tiles track
# Track generation: 1280..1605 -> 325-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 7           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.060779896 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0791     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0353     |
# |    std                  | 0.712       |
# |    value_loss           | 0.0826      |
# -----------------------------------------
# Track generation: 1068..1339 -> 271-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 8          |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.08618346 |
# |    clip_fraction        | 0.418      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0204    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0324    |
# |    std                  | 0.707      |
# |    value_loss           | 0.0846     |
# ----------------------------------------
# Track generation: 1089..1365 -> 276-tiles track
# Track generation: 1131..1423 -> 292-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 118       |
# |    iterations           | 9         |
# |    time_elapsed         | 154       |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0672923 |
# |    clip_fraction        | 0.42      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.19     |
# |    explained_variance   | 0.901     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0273    |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -0.0394   |
# |    std                  | 0.699     |
# |    value_loss           | 0.17      |
# ---------------------------------------
# Track generation: 1181..1480 -> 299-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 10         |
# |    time_elapsed         | 172        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.05809737 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0362    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0387    |
# |    std                  | 0.695      |
# |    value_loss           | 0.106      |
# ----------------------------------------
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 11         |
# |    time_elapsed         | 190        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.06389907 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0196    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0463    |
# |    std                  | 0.695      |
# |    value_loss           | 0.139      |
# ----------------------------------------
# Track generation: 1029..1293 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 12          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.077018365 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0391     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0459     |
# |    std                  | 0.687       |
# |    value_loss           | 0.0946      |
# -----------------------------------------
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 13         |
# |    time_elapsed         | 225        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.07999292 |
# |    clip_fraction        | 0.398      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0607    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0421    |
# |    std                  | 0.679      |
# |    value_loss           | 0.0467     |
# ----------------------------------------
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1188..1499 -> 311-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 117       |
# |    iterations           | 14        |
# |    time_elapsed         | 243       |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.1513775 |
# |    clip_fraction        | 0.448     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.06     |
# |    explained_variance   | 0.976     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0657   |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -0.047    |
# |    std                  | 0.667     |
# |    value_loss           | 0.0482    |
# ---------------------------------------
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 15         |
# |    time_elapsed         | 261        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.08037369 |
# |    clip_fraction        | 0.45       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.02      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0716    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0424    |
# |    std                  | 0.66       |
# |    value_loss           | 0.0705     |
# ----------------------------------------
# Track generation: 1220..1529 -> 309-tiles track
# Track generation: 1025..1285 -> 260-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 16         |
# |    time_elapsed         | 278        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.09984714 |
# |    clip_fraction        | 0.436      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.99      |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0615    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0464    |
# |    std                  | 0.655      |
# |    value_loss           | 0.0519     |
# ----------------------------------------
# Track generation: 1059..1336 -> 277-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 17          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.087904334 |
# |    clip_fraction        | 0.426       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0745     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0469     |
# |    std                  | 0.651       |
# |    value_loss           | 0.0498      |
# -----------------------------------------
# Track generation: 1133..1420 -> 287-tiles track
# Track generation: 1023..1283 -> 260-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 18         |
# |    time_elapsed         | 313        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.06136754 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.96      |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0541    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0319    |
# |    std                  | 0.651      |
# |    value_loss           | 0.0648     |
# ----------------------------------------
# Track generation: 1185..1485 -> 300-tiles track
# Track generation: 1162..1457 -> 295-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 19         |
# |    time_elapsed         | 331        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.08816147 |
# |    clip_fraction        | 0.461      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.94      |
# |    explained_variance   | 0.977      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0433    |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0349    |
# |    std                  | 0.641      |
# |    value_loss           | 0.0452     |
# ----------------------------------------
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1257..1575 -> 318-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 20          |
# |    time_elapsed         | 348         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.080287024 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0618     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0437     |
# |    std                  | 0.634       |
# |    value_loss           | 0.0437      |
# -----------------------------------------
# Track generation: 1012..1269 -> 257-tiles track
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 21         |
# |    time_elapsed         | 366        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.13825692 |
# |    clip_fraction        | 0.467      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.87      |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0578    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0494    |
# |    std                  | 0.627      |
# |    value_loss           | 0.0383     |
# ----------------------------------------
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1227..1538 -> 311-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 22         |
# |    time_elapsed         | 383        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.21535903 |
# |    clip_fraction        | 0.5        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.83      |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0849    |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0416    |
# |    std                  | 0.616      |
# |    value_loss           | 0.0412     |
# ----------------------------------------
# Track generation: 1176..1474 -> 298-tiles track
# Track generation: 1087..1363 -> 276-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 117       |
# |    iterations           | 23        |
# |    time_elapsed         | 401       |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.1457411 |
# |    clip_fraction        | 0.541     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.8      |
# |    explained_variance   | 0.98      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0793   |
# |    n_updates            | 520       |
# |    policy_gradient_loss | -0.0568   |
# |    std                  | 0.61      |
# |    value_loss           | 0.0485    |
# ---------------------------------------
# Track generation: 1214..1528 -> 314-tiles track
# Track generation: 1168..1464 -> 296-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 24         |
# |    time_elapsed         | 419        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.14551428 |
# |    clip_fraction        | 0.479      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.76      |
# |    explained_variance   | 0.979      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0381    |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0466    |
# |    std                  | 0.606      |
# |    value_loss           | 0.0488     |
# ----------------------------------------
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 25         |
# |    time_elapsed         | 437        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.10384898 |
# |    clip_fraction        | 0.451      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.72      |
# |    explained_variance   | 0.974      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0639    |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0464    |
# |    std                  | 0.597      |
# |    value_loss           | 0.0545     |
# ----------------------------------------
# Track generation: 1343..1683 -> 340-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 26         |
# |    time_elapsed         | 454        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.10488591 |
# |    clip_fraction        | 0.476      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.69      |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0558    |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.0466    |
# |    std                  | 0.588      |
# |    value_loss           | 0.0435     |
# ----------------------------------------
# Track generation: 1099..1378 -> 279-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 117       |
# |    iterations           | 27        |
# |    time_elapsed         | 472       |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.0815177 |
# |    clip_fraction        | 0.403     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.64     |
# |    explained_variance   | 0.989     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0788   |
# |    n_updates            | 560       |
# |    policy_gradient_loss | -0.0438   |
# |    std                  | 0.582     |
# |    value_loss           | 0.0352    |
# ---------------------------------------
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1074..1347 -> 273-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 28         |
# |    time_elapsed         | 489        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.13321817 |
# |    clip_fraction        | 0.487      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.6       |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0947    |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0604    |
# |    std                  | 0.575      |
# |    value_loss           | 0.0519     |
# ----------------------------------------
# Track generation: 1077..1358 -> 281-tiles track
# Track generation: 1306..1637 -> 331-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 29         |
# |    time_elapsed         | 507        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.19218232 |
# |    clip_fraction        | 0.508      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.59      |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0983    |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0601    |
# |    std                  | 0.571      |
# |    value_loss           | 0.0569     |
# ----------------------------------------
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1433..1795 -> 362-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 30         |
# |    time_elapsed         | 525        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.21375498 |
# |    clip_fraction        | 0.546      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.56      |
# |    explained_variance   | 0.929      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.114     |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.0686    |
# |    std                  | 0.562      |
# |    value_loss           | 0.0697     |
# ----------------------------------------
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1016..1274 -> 258-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 31         |
# |    time_elapsed         | 542        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.18484697 |
# |    clip_fraction        | 0.527      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.5       |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0894    |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.0631    |
# |    std                  | 0.551      |
# |    value_loss           | 0.0601     |
# ----------------------------------------
# Track generation: 1012..1278 -> 266-tiles track
# Track generation: 1027..1288 -> 261-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 32         |
# |    time_elapsed         | 560        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.15727198 |
# |    clip_fraction        | 0.517      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.45      |
# |    explained_variance   | 0.895      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0436    |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.048     |
# |    std                  | 0.546      |
# |    value_loss           | 0.144      |
# ----------------------------------------
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 1144..1441 -> 297-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 33         |
# |    time_elapsed         | 577        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.21688241 |
# |    clip_fraction        | 0.568      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.43      |
# |    explained_variance   | 0.834      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0775    |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.061     |
# |    std                  | 0.544      |
# |    value_loss           | 0.18       |
# ----------------------------------------
# Track generation: 1052..1319 -> 267-tiles track
# Track generation: 1124..1409 -> 285-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 34         |
# |    time_elapsed         | 595        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.21765257 |
# |    clip_fraction        | 0.586      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.41      |
# |    explained_variance   | 0.813      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0752    |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.0668    |
# |    std                  | 0.537      |
# |    value_loss           | 0.242      |
# ----------------------------------------
# Track generation: 1269..1591 -> 322-tiles track
# Track generation: 1272..1594 -> 322-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 35         |
# |    time_elapsed         | 613        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.25709283 |
# |    clip_fraction        | 0.623      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.38      |
# |    explained_variance   | 0.779      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0635    |
# |    n_updates            | 640        |
# |    policy_gradient_loss | -0.0554    |
# |    std                  | 0.532      |
# |    value_loss           | 0.206      |
# ----------------------------------------
# Track generation: 1050..1322 -> 272-tiles track
# Track generation: 1104..1390 -> 286-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 36         |
# |    time_elapsed         | 631        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.31984526 |
# |    clip_fraction        | 0.588      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.34      |
# |    explained_variance   | 0.879      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0708    |
# |    n_updates            | 650        |
# |    policy_gradient_loss | -0.071     |
# |    std                  | 0.521      |
# |    value_loss           | 0.143      |
# ----------------------------------------
# Track generation: 1210..1516 -> 306-tiles track
# Track generation: 1152..1448 -> 296-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1036..1301 -> 265-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1191..1493 -> 302-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 37         |
# |    time_elapsed         | 649        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.18352896 |
# |    clip_fraction        | 0.556      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.28      |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0712    |
# |    n_updates            | 660        |
# |    policy_gradient_loss | -0.0588    |
# |    std                  | 0.514      |
# |    value_loss           | 0.184      |
# ----------------------------------------
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1290..1617 -> 327-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 116      |
# |    iterations           | 38       |
# |    time_elapsed         | 667      |
# |    total_timesteps      | 77824    |
# | train/                  |          |
# |    approx_kl            | 0.288371 |
# |    clip_fraction        | 0.608    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.23    |
# |    explained_variance   | 0.913    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0646  |
# |    n_updates            | 670      |
# |    policy_gradient_loss | -0.0719  |
# |    std                  | 0.502    |
# |    value_loss           | 0.135    |
# --------------------------------------
# Track generation: 1141..1430 -> 289-tiles track
# Track generation: 1195..1505 -> 310-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 39         |
# |    time_elapsed         | 685        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.31508958 |
# |    clip_fraction        | 0.586      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 0.808      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0785    |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.0571    |
# |    std                  | 0.496      |
# |    value_loss           | 0.263      |
# ----------------------------------------
# Track generation: 1215..1523 -> 308-tiles track
# Track generation: 1123..1408 -> 285-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 116       |
# |    iterations           | 40        |
# |    time_elapsed         | 703       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.3551079 |
# |    clip_fraction        | 0.612     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.14     |
# |    explained_variance   | 0.855     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0985   |
# |    n_updates            | 690       |
# |    policy_gradient_loss | -0.0438   |
# |    std                  | 0.491     |
# |    value_loss           | 0.19      |
# ---------------------------------------
# Track generation: 960..1206 -> 246-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1195..1498 -> 303-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 41         |
# |    time_elapsed         | 721        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.27777255 |
# |    clip_fraction        | 0.597      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.11      |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0912    |
# |    n_updates            | 700        |
# |    policy_gradient_loss | -0.0656    |
# |    std                  | 0.485      |
# |    value_loss           | 0.156      |
# ----------------------------------------
# Track generation: 1085..1361 -> 276-tiles track
# Track generation: 1044..1344 -> 300-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1170..1467 -> 297-tiles track
# Track generation: 1181..1481 -> 300-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 42         |
# |    time_elapsed         | 739        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.26436317 |
# |    clip_fraction        | 0.625      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.08      |
# |    explained_variance   | 0.926      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0358    |
# |    n_updates            | 710        |
# |    policy_gradient_loss | -0.0527    |
# |    std                  | 0.48       |
# |    value_loss           | 0.15       |
# ----------------------------------------
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1367..1713 -> 346-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 43         |
# |    time_elapsed         | 756        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.25731754 |
# |    clip_fraction        | 0.628      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.03      |
# |    explained_variance   | 0.904      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0761    |
# |    n_updates            | 720        |
# |    policy_gradient_loss | -0.0692    |
# |    std                  | 0.471      |
# |    value_loss           | 0.188      |
# ----------------------------------------
# Track generation: 1231..1543 -> 312-tiles track
# Track generation: 1223..1533 -> 310-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 44         |
# |    time_elapsed         | 775        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.22986333 |
# |    clip_fraction        | 0.612      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.99      |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0762    |
# |    n_updates            | 730        |
# |    policy_gradient_loss | -0.0575    |
# |    std                  | 0.466      |
# |    value_loss           | 0.187      |
# ----------------------------------------
# Track generation: 1153..1447 -> 294-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1105..1389 -> 284-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1195..1498 -> 303-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 45         |
# |    time_elapsed         | 793        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.25662878 |
# |    clip_fraction        | 0.599      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.95      |
# |    explained_variance   | 0.881      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0923    |
# |    n_updates            | 740        |
# |    policy_gradient_loss | -0.0664    |
# |    std                  | 0.459      |
# |    value_loss           | 0.286      |
# ----------------------------------------
# Track generation: 1053..1329 -> 276-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 46         |
# |    time_elapsed         | 810        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.20259577 |
# |    clip_fraction        | 0.581      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.92      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.101     |
# |    n_updates            | 750        |
# |    policy_gradient_loss | -0.0594    |
# |    std                  | 0.456      |
# |    value_loss           | 0.0851     |
# ----------------------------------------
# Track generation: 1055..1331 -> 276-tiles track
# Track generation: 1161..1455 -> 294-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 116       |
# |    iterations           | 47        |
# |    time_elapsed         | 828       |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.2709394 |
# |    clip_fraction        | 0.573     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.86     |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0436   |
# |    n_updates            | 760       |
# |    policy_gradient_loss | -0.05     |
# |    std                  | 0.444     |
# |    value_loss           | 0.0833    |
# ---------------------------------------
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1211..1518 -> 307-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 48         |
# |    time_elapsed         | 846        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.17156154 |
# |    clip_fraction        | 0.554      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.8       |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0541    |
# |    n_updates            | 770        |
# |    policy_gradient_loss | -0.047     |
# |    std                  | 0.438      |
# |    value_loss           | 0.0855     |
# ----------------------------------------
# Track generation: 1175..1473 -> 298-tiles track
# Track generation: 1291..1618 -> 327-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 49         |
# |    time_elapsed         | 864        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.34811383 |
# |    clip_fraction        | 0.657      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.75      |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0808    |
# |    n_updates            | 780        |
# |    policy_gradient_loss | -0.0664    |
# |    std                  | 0.428      |
# |    value_loss           | 0.186      |
# ----------------------------------------
# Track generation: 1032..1300 -> 268-tiles track
# Track generation: 1182..1490 -> 308-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 50         |
# |    time_elapsed         | 882        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.23821104 |
# |    clip_fraction        | 0.629      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.7       |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0814    |
# |    n_updates            | 790        |
# |    policy_gradient_loss | -0.0665    |
# |    std                  | 0.422      |
# |    value_loss           | 0.137      |
# ----------------------------------------
# Track generation: 1052..1319 -> 267-tiles track
# Track generation: 1156..1452 -> 296-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 116       |
# |    iterations           | 51        |
# |    time_elapsed         | 899       |
# |    total_timesteps      | 104448    |
# | train/                  |           |
# |    approx_kl            | 0.2555223 |
# |    clip_fraction        | 0.603     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.65     |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0839   |
# |    n_updates            | 800       |
# |    policy_gradient_loss | -0.0612   |
# |    std                  | 0.413     |
# |    value_loss           | 0.0931    |
# ---------------------------------------
# Track generation: 1043..1308 -> 265-tiles track
# Track generation: 1159..1459 -> 300-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 52         |
# |    time_elapsed         | 917        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.27161023 |
# |    clip_fraction        | 0.64       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.91       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0704    |
# |    n_updates            | 810        |
# |    policy_gradient_loss | -0.0477    |
# |    std                  | 0.405      |
# |    value_loss           | 0.227      |
# ----------------------------------------
# Track generation: 1208..1522 -> 314-tiles track
# Track generation: 1292..1619 -> 327-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 53         |
# |    time_elapsed         | 935        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.24618487 |
# |    clip_fraction        | 0.598      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0843    |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.0597    |
# |    std                  | 0.4        |
# |    value_loss           | 0.116      |
# ----------------------------------------
# Track generation: 1074..1355 -> 281-tiles track
# Track generation: 1376..1724 -> 348-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 54         |
# |    time_elapsed         | 953        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.26333547 |
# |    clip_fraction        | 0.614      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | 0.978      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0621    |
# |    n_updates            | 830        |
# |    policy_gradient_loss | -0.062     |
# |    std                  | 0.392      |
# |    value_loss           | 0.127      |
# ----------------------------------------
# ...
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0126    |
# |    n_updates            | 8100      |
# |    policy_gradient_loss | 0.0347    |
# |    std                  | 0.0132    |
# |    value_loss           | 0.0414    |
# ---------------------------------------
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1181..1487 -> 306-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 782       |
# |    time_elapsed         | 14275     |
# |    total_timesteps      | 1601536   |
# | train/                  |           |
# |    approx_kl            | 1.3000827 |
# |    clip_fraction        | 0.81      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.82      |
# |    explained_variance   | 0.908     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0421   |
# |    n_updates            | 8110      |
# |    policy_gradient_loss | 0.000397  |
# |    std                  | 0.0131    |
# |    value_loss           | 0.105     |
# ---------------------------------------
# Track generation: 1260..1579 -> 319-tiles track
# Track generation: 1151..1443 -> 292-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 783       |
# |    time_elapsed         | 14294     |
# |    total_timesteps      | 1603584   |
# | train/                  |           |
# |    approx_kl            | 0.9949257 |
# |    clip_fraction        | 0.756     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.85      |
# |    explained_variance   | 0.962     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0231   |
# |    n_updates            | 8120      |
# |    policy_gradient_loss | -0.0103   |
# |    std                  | 0.013     |
# |    value_loss           | 0.0486    |
# ---------------------------------------
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 784       |
# |    time_elapsed         | 14312     |
# |    total_timesteps      | 1605632   |
# | train/                  |           |
# |    approx_kl            | 1.1004939 |
# |    clip_fraction        | 0.81      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.88      |
# |    explained_variance   | 0.982     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0549   |
# |    n_updates            | 8130      |
# |    policy_gradient_loss | -0.00107  |
# |    std                  | 0.0129    |
# |    value_loss           | 0.0372    |
# ---------------------------------------
# Track generation: 1106..1395 -> 289-tiles track
# Track generation: 1123..1408 -> 285-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 785       |
# |    time_elapsed         | 14331     |
# |    total_timesteps      | 1607680   |
# | train/                  |           |
# |    approx_kl            | 1.6305015 |
# |    clip_fraction        | 0.849     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.89      |
# |    explained_variance   | 0.979     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.025    |
# |    n_updates            | 8140      |
# |    policy_gradient_loss | 0.0272    |
# |    std                  | 0.0129    |
# |    value_loss           | 0.0406    |
# ---------------------------------------
# Track generation: 1029..1300 -> 271-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 786       |
# |    time_elapsed         | 14351     |
# |    total_timesteps      | 1609728   |
# | train/                  |           |
# |    approx_kl            | 1.3678854 |
# |    clip_fraction        | 0.824     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.89      |
# |    explained_variance   | 0.97      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00199   |
# |    n_updates            | 8150      |
# |    policy_gradient_loss | 0.008     |
# |    std                  | 0.0128    |
# |    value_loss           | 0.0579    |
# ---------------------------------------
# Track generation: 1131..1426 -> 295-tiles track
# Track generation: 1110..1392 -> 282-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 112      |
# |    iterations           | 787      |
# |    time_elapsed         | 14372    |
# |    total_timesteps      | 1611776  |
# | train/                  |          |
# |    approx_kl            | 2.105742 |
# |    clip_fraction        | 0.856    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 8.89     |
# |    explained_variance   | 0.886    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0318  |
# |    n_updates            | 8160     |
# |    policy_gradient_loss | 0.0185   |
# |    std                  | 0.0129   |
# |    value_loss           | 0.172    |
# --------------------------------------
# Track generation: 1271..1592 -> 321-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 788       |
# |    time_elapsed         | 14392     |
# |    total_timesteps      | 1613824   |
# | train/                  |           |
# |    approx_kl            | 1.2138473 |
# |    clip_fraction        | 0.792     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.89      |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0292   |
# |    n_updates            | 8170      |
# |    policy_gradient_loss | -0.00164  |
# |    std                  | 0.0129    |
# |    value_loss           | 0.0743    |
# ---------------------------------------
# Track generation: 1110..1392 -> 282-tiles track
# Track generation: 1227..1543 -> 316-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 789       |
# |    time_elapsed         | 14411     |
# |    total_timesteps      | 1615872   |
# | train/                  |           |
# |    approx_kl            | 0.9891448 |
# |    clip_fraction        | 0.795     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.87      |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00648  |
# |    n_updates            | 8180      |
# |    policy_gradient_loss | 0.00896   |
# |    std                  | 0.013     |
# |    value_loss           | 0.0624    |
# ---------------------------------------
# Track generation: 1061..1338 -> 277-tiles track
# Track generation: 1063..1333 -> 270-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 790        |
# |    time_elapsed         | 14429      |
# |    total_timesteps      | 1617920    |
# | train/                  |            |
# |    approx_kl            | 0.84589255 |
# |    clip_fraction        | 0.77       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 8.89       |
# |    explained_variance   | 0.974      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0426    |
# |    n_updates            | 8190       |
# |    policy_gradient_loss | -0.0156    |
# |    std                  | 0.0128     |
# |    value_loss           | 0.037      |
# ----------------------------------------
# Track generation: 1272..1594 -> 322-tiles track
# Track generation: 1197..1500 -> 303-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 791       |
# |    time_elapsed         | 14448     |
# |    total_timesteps      | 1619968   |
# | train/                  |           |
# |    approx_kl            | 1.1636708 |
# |    clip_fraction        | 0.801     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.93      |
# |    explained_variance   | 0.983     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0339   |
# |    n_updates            | 8200      |
# |    policy_gradient_loss | -0.012    |
# |    std                  | 0.0127    |
# |    value_loss           | 0.0308    |
# ---------------------------------------
# Track generation: 1151..1443 -> 292-tiles track
# Track generation: 1112..1394 -> 282-tiles track
# Track generation: 1194..1503 -> 309-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 792       |
# |    time_elapsed         | 14466     |
# |    total_timesteps      | 1622016   |
# | train/                  |           |
# |    approx_kl            | 1.3129416 |
# |    clip_fraction        | 0.8       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.96      |
# |    explained_variance   | 0.942     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00152   |
# |    n_updates            | 8210      |
# |    policy_gradient_loss | 0.0256    |
# |    std                  | 0.0127    |
# |    value_loss           | 0.0641    |
# ---------------------------------------
# Track generation: 1173..1471 -> 298-tiles track
# Track generation: 1319..1653 -> 334-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 793       |
# |    time_elapsed         | 14483     |
# |    total_timesteps      | 1624064   |
# | train/                  |           |
# |    approx_kl            | 1.1163505 |
# |    clip_fraction        | 0.81      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.93      |
# |    explained_variance   | 0.989     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0487    |
# |    n_updates            | 8220      |
# |    policy_gradient_loss | 0.014     |
# |    std                  | 0.0128    |
# |    value_loss           | 0.0331    |
# ---------------------------------------
# Track generation: 1347..1688 -> 341-tiles track
# Track generation: 1088..1364 -> 276-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 794       |
# |    time_elapsed         | 14502     |
# |    total_timesteps      | 1626112   |
# | train/                  |           |
# |    approx_kl            | 1.0698555 |
# |    clip_fraction        | 0.801     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.93      |
# |    explained_variance   | 0.976     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0484   |
# |    n_updates            | 8230      |
# |    policy_gradient_loss | -0.00921  |
# |    std                  | 0.0127    |
# |    value_loss           | 0.0417    |
# ---------------------------------------
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1100..1379 -> 279-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 795       |
# |    time_elapsed         | 14520     |
# |    total_timesteps      | 1628160   |
# | train/                  |           |
# |    approx_kl            | 1.1999832 |
# |    clip_fraction        | 0.792     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.93      |
# |    explained_variance   | 0.966     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0409   |
# |    n_updates            | 8240      |
# |    policy_gradient_loss | 0.0051    |
# |    std                  | 0.0127    |
# |    value_loss           | 0.0509    |
# ---------------------------------------
# Track generation: 1145..1440 -> 295-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 796       |
# |    time_elapsed         | 14538     |
# |    total_timesteps      | 1630208   |
# | train/                  |           |
# |    approx_kl            | 1.2008108 |
# |    clip_fraction        | 0.805     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 8.93      |
# |    explained_variance   | 0.985     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0418    |
# |    n_updates            | 8250      |
# |    policy_gradient_loss | 0.0121    |
# |    std                  | 0.0127    |
# |    value_loss           | 0.0361    |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15544/786343116.py in <module>
# ----> 1 model.learn(total_timesteps = 10000000)
#
# ~\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     297     ) -> "PPO":
#     298
# --> 299         return super(PPO, self).learn(
#     300             total_timesteps=total_timesteps,
#     301             callback=callback,
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     268                 self.logger.dump(step=self.num_timesteps)
#     269
# --> 270             self.train()
#     271
#     272         callback.on_training_end()
#
# ~\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py in train(self)
#     197                     self.policy.reset_noise(self.batch_size)
#     198
# --> 199                 values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     200                 values = values.flatten()
#     201                 # Normalize advantage
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\policies.py in evaluate_actions(self, obs, actions)
#     644         latent_pi, latent_vf = self.mlp_extractor(features)
#     645         distribution = self._get_action_dist_from_latent(latent_pi)
# --> 646         log_prob = distribution.log_prob(actions)
#     647         values = self.value_net(latent_vf)
#     648         return values, log_prob, distribution.entropy()
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\distributions.py in log_prob(self, actions)
#     161         :return:
#     162         """
# --> 163         log_prob = self.distribution.log_prob(actions)
#     164         return sum_independent_dims(log_prob)
#     165
#
# ~\anaconda3\lib\site-packages\torch\distributions\normal.py in log_prob(self, value)
#      73             self._validate_sample(value)
#      74         # compute the variance
# ---> 75         var = (self.scale ** 2)
#      76         log_scale = math.log(self.scale) if isinstance(self.scale, Real) else self.scale.log()
#      77         return -((value - self.loc) ** 2) / (2 * var) - log_scale - math.log(math.sqrt(2 * math.pi))
#
# ~\anaconda3\lib\site-packages\torch\_tensor.py in wrapped(*args, **kwargs)
#      28             return handle_torch_function(wrapped, args, *args, **kwargs)
#      29         try:
# ---> 30             return f(*args, **kwargs)
#      31         except TypeError:
#      32             return NotImplemented
#
# KeyboardInterrupt:

# %% [markdown]
# # Salvando modelo

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_10M_Model')

# %%
model.save(ppo_path)

# %%
del model

# %%
model = PPO.load(ppo_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# # Avaliação

# %%
evaluate_policy(model, env, n_eval_episodes = 10, render = True)
# Out:
# Track generation: 1335..1673 -> 338-tiles track

# %%
env.close()
